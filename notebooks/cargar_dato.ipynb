# %%
import pandas as pd

# %%
df = pd.read_csv('../data/raw/dataset_elpino.csv', sep=';')
df.head()
# Out:
#                          Diag 01 Principal (cod+des)  \
# 0            A41.8 - Otras septicemias especificadas
# 1               U07.1 - COVID-19, virus identificado
# 2  K56.5 - Adherencias [bridas] intestinales con ...
# 3  K76.8 - Otras enfermedades especificadas del h...
# 4  T81.0 - Hemorragia y hematoma que complican un...
#
#                         Diag 02 Secundario (cod+des)  \
# 0     B37.6 - Endocarditis debida a candida (I39.8*)
# 1              J12.8 - Neumonía debida a otros virus
# 2                              R57.2 - Shock séptico
# 3                              K66.1 - Hemoperitoneo
# 4  Y83.2 - Operación quirúrgica con anastomosis, ...
#
#                         Diag 03 Secundario (cod+des)  \
# 0  I39.8 - Endocarditis, válvula no especificada,...
# 1                                     R06.0 - Disnea
# 2                        R57.1 - Choque hipovolémico
# 3        N18.5 - Enfermedad renal crónica, estadio 5
# 4               S31.1 - Herida de la pared abdominal
#
#                         Diag 04 Secundario (cod+des)  \
# 0            N10 - Nefritis tubulointersticial aguda
# 1                                          R05 - Tos
# 2  J80 - Síndrome de dificultad respiratoria del ...
# 3             D64.9 - Anemia de tipo no especificado
# 4  S36.80 - Traumatismo de otros órganos intraabd...
#
#                         Diag 05 Secundario (cod+des)  \
# 0  B96.1 - Klebsiella pneumoniae [K. pneumoniae] ...
# 1                    R50.9 - Fiebre, no especificada
# 2                          Y95 - Afección nosocomial
# 3                             E87.5 - Hiperpotasemia
# 4  W31.62 - Contacto traumático con otras maquina...
#
#                         Diag 06 Secundario (cod+des)  \
# 0  L89.9 - Úlcera de decúbito y area de presión n...
# 1                                Z29.0 - Aislamiento
# 2    J15.0 - Neumonía debida a Klebsiella pneumoniae
# 3                                   E87.2 - Acidosis
# 4  J96.09 - Insuficiencia respiratoria aguda, Tip...
#
#                         Diag 07 Secundario (cod+des)  \
# 0  L08.9 - Infección local de la piel y del tejid...
# 1                      Z01.7 - Examen de laboratorio
# 2  U82.2 - Resistencia a Betalactamasas de amplio...
# 3                               J81 - Edema pulmonar
# 4    J15.0 - Neumonía debida a Klebsiella pneumoniae
#
#                         Diag 08 Secundario (cod+des)  \
# 0  B96.2 - Escherichia coli [E. coli] como causa ...
# 1  J96.00 - Insuficiencia respiratoria aguda, Tip...
# 2  B95.6 - Staphylococcus aureus como causa de en...
# 3        N17.8 - Otras insuficiencias renales agudas
# 4  U82.2 - Resistencia a Betalactamasas de amplio...
#
#                         Diag 09 Secundario (cod+des)  \
# 0  A41.5 - Sepsis por otros organnismos Gram nega...
# 1                                  J94.2 - Hemotórax
# 2  B96.8 - Otros agentes bacterianos especificado...
# 3  J44.9 - Enfermedad pulmonar obstructiva crónic...
# 4               U07.1 - COVID-19, virus identificado
#
#                         Diag 10 Secundario (cod+des)  ...  \
# 0                       J86.9 - Piotórax sin fístula  ...
# 1              J92.9 - Paquipleuritis sin asbestosis  ...
# 2                       B37.1 - Candidiasis pulmonar  ...
# 3             R41.0 - Desorientación no especificada  ...
# 4  N39.0 - Infección de vías urinarias, sitio no ...  ...
#
#                Proced 24 Secundario (cod+des)  \
# 0                         99.84 - AISLAMIENTO
# 1    91.62 - EXAMEN MICROSCOPICO PIEL.CULTIVO
# 2                         99.84 - AISLAMIENTO
# 3         57.94 - SONDAJE URINARIO PERMANENTE
# 4  90.52 - EXAMEN MICROSCOPICO SANGRE.CULTIVO
#
#                       Proced 25 Secundario (cod+des)  \
# 0                            88.72 - ECOCARDIOGRAFIA
# 1  90.43 - EXAMEN MICROSCOPICO RESPIRATORIO.CULTI...
# 2  91.73 - EXAMEN MICROSCOPICO HERIDA OPERATORIA....
# 3                       00.13 - INYECCION NESIRITIDE
# 4  91.39 - EXAMEN MICROSCOPICO URINARIO INFERIOR....
#
#                       Proced 26 Secundario (cod+des)  \
# 0   90.42 - EXAMEN MICROSCOPICO RESPIRATORIO.CULTIVO
# 1  91.39 - EXAMEN MICROSCOPICO URINARIO INFERIOR....
# 2  90.53 - EXAMEN MICROSCOPICO SANGRE.CULTIVO Y S...
# 3                  00.17 - INFUSON AGENTE VASOPRESOR
# 4  91.32 - EXAMEN MICROSCOPICO URINARIO INFERIOR....
#
#                       Proced 27 Secundario (cod+des)  \
# 0         90.52 - EXAMEN MICROSCOPICO SANGRE.CULTIVO
# 1         90.52 - EXAMEN MICROSCOPICO SANGRE.CULTIVO
# 2                   99.26 - INYECCION TRANQUILIZANTE
# 3           99.04 - TRANSFUSION CONCENTRADO HEMATIES
# 4  93.90 - RESPIRACION PRESION POSITIVA CONTINUA ...
#
#                       Proced 28 Secundario (cod+des)  \
# 0  91.39 - EXAMEN MICROSCOPICO URINARIO INFERIOR....
# 1  91.32 - EXAMEN MICROSCOPICO URINARIO INFERIOR....
# 2  89.39 - OTRAS MEDICIONES Y EXAMENES NO QUIRURG...
# 3                      99.18 - INYECCION ELECTROLITO
# 4  99.15 - INFUSION PARENTERAL SUSTANCIA NUTRITIV...
#
#                       Proced 29 Secundario (cod+des)  \
# 0  91.33 - EXAMEN MICROSCOPICO URINARIO INFERIOR....
# 1                     96.59 - IRRIGACION HERIDA OTRA
# 2                            89.66 - GASOMETRIA VENA
# 3                      99.21 - INYECCION ANTIBIOTICO
# 4                     96.59 - IRRIGACION HERIDA OTRA
#
#                       Proced 30 Secundario (cod+des) Edad en años Sexo (Desc)  \
# 0      87.03 - TOMOGRAFIA AXIAL COMPUTERIZADA CABEZA           40      Hombre
# 1  90.99 - EXAMEN MICROSCOPICO DIGESTIVO INFERIOR...           53      Hombre
# 2                         89.65 - GASOMETRIA ARTERIA           65      Hombre
# 3                        99.23 - INYECCION ESTEROIDE           61      Hombre
# 4           45.13 - ESOFAGOGASTRODUODENOSCOPIA [EGD]           30      Hombre
#
#                                                  GRD
# 0                       184103 - MH SEPTICEMIA W/MCC
# 1  041013 - PH ECMO VENTILACIÓN MECÁNICA PROLONGA...
# 2  041013 - PH ECMO VENTILACIÓN MECÁNICA PROLONGA...
# 3  041023 - PH VENTILACIÓN MECÁNICA PROLONGADA SI...
# 4  041023 - PH VENTILACIÓN MECÁNICA PROLONGADA SI...
#
# [5 rows x 68 columns]

# %%
import sys
sys.path.append("..")


from src.data.EDA import EDA
eda = EDA()
eda.summaryEda(df, 'GRD')
# Out:
# Tipos de datos:
#                                   tipo
# Diag 01 Principal (cod+des)     object
# Diag 02 Secundario (cod+des)    object
# Diag 03 Secundario (cod+des)    object
# Diag 04 Secundario (cod+des)    object
# Diag 05 Secundario (cod+des)    object
# ...                                ...
# Proced 29 Secundario (cod+des)  object
# Proced 30 Secundario (cod+des)  object
# Edad en años                     int64
# Sexo (Desc)                     object
# GRD                             object
#
# [68 rows x 1 columns]
#  Valores faltantes por columna
#                                 Valores faltantes
# Diag 01 Principal (cod+des)                     0
# Diag 02 Secundario (cod+des)                    0
# Diag 03 Secundario (cod+des)                    0
# Diag 04 Secundario (cod+des)                    0
# Diag 05 Secundario (cod+des)                    0
# ...                                           ...
# Proced 29 Secundario (cod+des)                  0
# Proced 30 Secundario (cod+des)                  0
# Edad en años                                    0
# Sexo (Desc)                                     0
# GRD                                             0
#
# [68 rows x 1 columns]
# Variables con alta cardinalidad ( > 100 categorías):
#                                 Unique_Values
# Diag 02 Secundario (cod+des)             1717
# Diag 03 Secundario (cod+des)             1498
# Diag 01 Principal (cod+des)              1491
# Diag 04 Secundario (cod+des)             1304
# Diag 05 Secundario (cod+des)             1151
# Diag 06 Secundario (cod+des)              982
# Diag 07 Secundario (cod+des)              838
# Diag 08 Secundario (cod+des)              752
# Diag 09 Secundario (cod+des)              664
# Diag 10 Secundario (cod+des)              598
# Diag 11 Secundario (cod+des)              561
# Proced 01 Principal (cod+des)             528
# GRD                                       526
# Diag 12 Secundario (cod+des)              522
# Proced 02 Secundario (cod+des)            496
# Diag 13 Secundario (cod+des)              447
# Diag 14 Secundario (cod+des)              409
# Proced 03 Secundario (cod+des)            385
# Diag 15 Secundario (cod+des)              359
# Diag 16 Secundario (cod+des)              317
# Diag 17 Secundario (cod+des)              301
# Proced 04 Secundario (cod+des)            287
# Diag 18 Secundario (cod+des)              268
# Proced 05 Secundario (cod+des)            259
# Proced 06 Secundario (cod+des)            246
# Proced 07 Secundario (cod+des)            223
# Diag 19 Secundario (cod+des)              216
# Proced 08 Secundario (cod+des)            214
# Proced 09 Secundario (cod+des)            209
# Proced 10 Secundario (cod+des)            196
# Diag 20 Secundario (cod+des)              194
# Diag 21 Secundario (cod+des)              186
# Proced 11 Secundario (cod+des)            179
# Proced 12 Secundario (cod+des)            178
# Proced 13 Secundario (cod+des)            174
# Diag 22 Secundario (cod+des)              171
# Proced 14 Secundario (cod+des)            165
# Proced 15 Secundario (cod+des)            155
# Proced 16 Secundario (cod+des)            153
# Diag 23 Secundario (cod+des)              144
# Proced 17 Secundario (cod+des)            136
# Proced 19 Secundario (cod+des)            134
# Proced 18 Secundario (cod+des)            129
# Proced 20 Secundario (cod+des)            127
# Proced 23 Secundario (cod+des)            122
# Diag 24 Secundario (cod+des)              122
# Diag 25 Secundario (cod+des)              118
# Proced 22 Secundario (cod+des)            118
# Proced 24 Secundario (cod+des)            115
# Proced 25 Secundario (cod+des)            112
# Proced 21 Secundario (cod+des)            111
# Proced 26 Secundario (cod+des)            111
# Proced 27 Secundario (cod+des)            103
#  Estadística descriptiva
#                                   count unique  \
# Diag 01 Principal (cod+des)       14561   1491
# Diag 02 Secundario (cod+des)      14561   1717
# Diag 03 Secundario (cod+des)      14561   1498
# Diag 04 Secundario (cod+des)      14561   1304
# Diag 05 Secundario (cod+des)      14561   1151
# ...                                 ...    ...
# Proced 29 Secundario (cod+des)    14561     93
# Proced 30 Secundario (cod+des)    14561     92
# Edad en años                    14561.0    NaN
# Sexo (Desc)                       14561      2
# GRD                               14561    526
#
#                                                                               top  \
# Diag 01 Principal (cod+des)     O70.0 - Desgarro perineal de primer grado dura...
# Diag 02 Secundario (cod+des)                                                    -
# Diag 03 Secundario (cod+des)                                                    -
# Diag 04 Secundario (cod+des)                                                    -
# Diag 05 Secundario (cod+des)                                                    -
# ...                                                                           ...
# Proced 29 Secundario (cod+des)                                                  -
# Proced 30 Secundario (cod+des)                                                  -
# Edad en años                                                                  NaN
# Sexo (Desc)                                                                 Mujer
# GRD                                                           146101 - PH CESÁREA
#
#                                  freq      mean        std  min   25%   50%  \
# Diag 01 Principal (cod+des)       779       NaN        NaN  NaN   NaN   NaN
# Diag 02 Secundario (cod+des)     1209       NaN        NaN  NaN   NaN   NaN
# Diag 03 Secundario (cod+des)     2687       NaN        NaN  NaN   NaN   NaN
# Diag 04 Secundario (cod+des)     4127       NaN        NaN  NaN   NaN   NaN
# Diag 05 Secundario (cod+des)     5371       NaN        NaN  NaN   NaN   NaN
# ...                               ...       ...        ...  ...   ...   ...
# Proced 29 Secundario (cod+des)  13379       NaN        NaN  NaN   NaN   NaN
# Proced 30 Secundario (cod+des)  13498       NaN        NaN  NaN   NaN   NaN
# Edad en años                      NaN  39.42655  24.681545  0.0  23.0  36.0
# Sexo (Desc)                      9617       NaN        NaN  NaN   NaN   NaN
# GRD                               813       NaN        NaN  NaN   NaN   NaN
#
#                                  75%    max
# Diag 01 Principal (cod+des)      NaN    NaN
# Diag 02 Secundario (cod+des)     NaN    NaN
# Diag 03 Secundario (cod+des)     NaN    NaN
# Diag 04 Secundario (cod+des)     NaN    NaN
# Diag 05 Secundario (cod+des)     NaN    NaN
# ...                              ...    ...
# Proced 29 Secundario (cod+des)   NaN    NaN
# Proced 30 Secundario (cod+des)   NaN    NaN
# Edad en años                    60.0  121.0
# Sexo (Desc)                      NaN    NaN
# GRD                              NaN    NaN
#
# [68 rows x 11 columns]
# Distribución de la variable objetivo:
#                                                     conteo
# GRD
# 146101 - PH CESÁREA                                    813
# 146121 - PH PARTO VAGINAL CON PROCED., EXCEPTO ...     639
# 146131 - PH PARTO VAGINAL                              538
# 158171 - MH NEONATO, PESO AL NACER >2499 GR SIN...     389
# 134161 - MH TRASTORNOS DEL ANTEPARTO                   325
# ...                                                    ...
# 214103 - MH LESIONES DE MÚLTIPLES SITIOS NO ESP...       1
# 054223 - MH MIOCARDIOPATÍA W/MCC                         1
# 114142 - MH DISFUNCIÓN, REACCIÓN O COMPL. POR D...       1
# 131122 - PH INTERRUPCIÓN TUBÁRICA ABIERTA W/CC           1
# 134153 - MH FALSO TRABAJO DEL PARTO W/MCC                1
#
# [526 rows x 1 columns]
# Columnas categóricas - Top 5 valores:
#
# Diag 01 Principal (cod+des):
# Diag 01 Principal (cod+des)
# O70.0 - Desgarro perineal de primer grado durante el parto                       779
# O80.0 - Parto único espontáneo, presentación cefálica de vértice                 471
# U07.1 - COVID-19, virus identificado                                             327
# O34.2 - Atención materna por cicatriz uterina debida a cirugía previa            304
# E11.5 - Diabetes mellitus tipo 2 con complicaciones circulatorias periféricas    215
# Name: count, dtype: int64
#
# Diag 02 Secundario (cod+des):
# Diag 02 Secundario (cod+des)
# -                                                                   1209
# I10 - Hipertensión esencial (primaria)                               828
# O80.0 - Parto único espontáneo, presentación cefálica de vértice     704
# J96.09 - Insuficiencia respiratoria aguda, Tipo no especificado      369
# J12.8 - Neumonía debida a otros virus                                332
# Name: count, dtype: int64
#
# Diag 03 Secundario (cod+des):
# Diag 03 Secundario (cod+des)
# -                                                                                                                        2687
# I10 - Hipertensión esencial (primaria)                                                                                    664
# Z37.0 - Nacido vivo, único                                                                                                495
# E11.9 - Diabetes mellitus tipo 2 sin complicaciones                                                                       360
# O99.2 - Enfermedades endocrinas, de la nutrición y del metabolismo que complican el embarazo, el parto y el puerperio     285
# Name: count, dtype: int64
#
# Diag 04 Secundario (cod+des):
# Diag 04 Secundario (cod+des)
# -                                             4127
# Z37.0 - Nacido vivo, único                     521
# Z38.0 - Producto único, nacido en hospital     495
# I10 - Hipertensión esencial (primaria)         477
# E66.9 - Obesidad, no especificada              363
# Name: count, dtype: int64
#
# Diag 05 Secundario (cod+des):
# Diag 05 Secundario (cod+des)
# -                                                             5371
# Z37.0 - Nacido vivo, único                                     530
# Z38.0 - Producto único, nacido en hospital                     525
# Z39.0 - Atención y examen inmediatamente después del parto     498
# I10 - Hipertensión esencial (primaria)                         409
# Name: count, dtype: int64
#
# Diag 06 Secundario (cod+des):
# Diag 06 Secundario (cod+des)
# -                                                             6394
# Z38.0 - Producto único, nacido en hospital                     534
# Z39.0 - Atención y examen inmediatamente después del parto     528
# Z39.1 - Atención y examen de madre en período de lactancia     496
# Z37.0 - Nacido vivo, único                                     430
# Name: count, dtype: int64
#
# Diag 07 Secundario (cod+des):
# Diag 07 Secundario (cod+des)
# -                                                             7408
# Z39.0 - Atención y examen inmediatamente después del parto     537
# Z39.1 - Atención y examen de madre en período de lactancia     528
# Z39.2 - Seguimiento postparto, de rutina                       499
# Z38.0 - Producto único, nacido en hospital                     429
# Name: count, dtype: int64
#
# Diag 08 Secundario (cod+des):
# Diag 08 Secundario (cod+des)
# -                                                             8584
# Z39.1 - Atención y examen de madre en período de lactancia     536
# Z39.2 - Seguimiento postparto, de rutina                       530
# Z39.0 - Atención y examen inmediatamente después del parto     438
# Z38.0 - Producto único, nacido en hospital                     328
# Name: count, dtype: int64
#
# Diag 09 Secundario (cod+des):
# Diag 09 Secundario (cod+des)
# -                                                             9719
# Z39.2 - Seguimiento postparto, de rutina                       539
# Z39.1 - Atención y examen de madre en período de lactancia     436
# Z39.0 - Atención y examen inmediatamente después del parto     337
# Z38.0 - Producto único, nacido en hospital                     213
# Name: count, dtype: int64
#
# Diag 10 Secundario (cod+des):
# Diag 10 Secundario (cod+des)
# -                                                                                     10696
# Z39.2 - Seguimiento postparto, de rutina                                                438
# Z39.1 - Atención y examen de madre en período de lactancia                              333
# Z39.0 - Atención y examen inmediatamente después del parto                              216
# Z92.2 - Historia personal de uso (presente) de otros medicamentos por largo tiempo      175
# Name: count, dtype: int64
#
# Diag 11 Secundario (cod+des):
# Diag 11 Secundario (cod+des)
# -                                                                                     11574
# Z39.2 - Seguimiento postparto, de rutina                                                334
# Z39.1 - Atención y examen de madre en período de lactancia                              217
# Z92.2 - Historia personal de uso (presente) de otros medicamentos por largo tiempo      132
# Z39.0 - Atención y examen inmediatamente después del parto                              109
# Name: count, dtype: int64
#
# Diag 12 Secundario (cod+des):
# Diag 12 Secundario (cod+des)
# -                                                                                     12238
# Z39.2 - Seguimiento postparto, de rutina                                                215
# Z92.2 - Historia personal de uso (presente) de otros medicamentos por largo tiempo      119
# Z39.1 - Atención y examen de madre en período de lactancia                              108
# I10 - Hipertensión esencial (primaria)                                                   72
# Name: count, dtype: int64
#
# Diag 13 Secundario (cod+des):
# Diag 13 Secundario (cod+des)
# -                                                                                     12761
# Z39.2 - Seguimiento postparto, de rutina                                                110
# Z92.2 - Historia personal de uso (presente) de otros medicamentos por largo tiempo      106
# I10 - Hipertensión esencial (primaria)                                                   63
# Z39.1 - Atención y examen de madre en período de lactancia                               56
# Name: count, dtype: int64
#
# Diag 14 Secundario (cod+des):
# Diag 14 Secundario (cod+des)
# -                                                                                     13130
# Z92.2 - Historia personal de uso (presente) de otros medicamentos por largo tiempo       84
# Z39.2 - Seguimiento postparto, de rutina                                                 57
# I10 - Hipertensión esencial (primaria)                                                   50
# Z92.4 - Historia personal de cirugía mayor, no clasificada en otra parte                 42
# Name: count, dtype: int64
#
# Diag 15 Secundario (cod+des):
# Diag 15 Secundario (cod+des)
# -                                                                                     13423
# Z92.2 - Historia personal de uso (presente) de otros medicamentos por largo tiempo       75
# Z39.2 - Seguimiento postparto, de rutina                                                 34
# I10 - Hipertensión esencial (primaria)                                                   32
# Z92.4 - Historia personal de cirugía mayor, no clasificada en otra parte                 28
# Name: count, dtype: int64
#
# Diag 16 Secundario (cod+des):
# Diag 16 Secundario (cod+des)
# -                                                                                     13638
# Z92.2 - Historia personal de uso (presente) de otros medicamentos por largo tiempo       63
# I10 - Hipertensión esencial (primaria)                                                   34
# Z92.4 - Historia personal de cirugía mayor, no clasificada en otra parte                 28
# Z51.5 - Atención paliativa                                                               18
# Name: count, dtype: int64
#
# Diag 17 Secundario (cod+des):
# Diag 17 Secundario (cod+des)
# -                                                                                     13802
# Z92.2 - Historia personal de uso (presente) de otros medicamentos por largo tiempo       58
# I10 - Hipertensión esencial (primaria)                                                   25
# Z92.4 - Historia personal de cirugía mayor, no clasificada en otra parte                 22
# E11.9 - Diabetes mellitus tipo 2 sin complicaciones                                      19
# Name: count, dtype: int64
#
# Diag 18 Secundario (cod+des):
# Diag 18 Secundario (cod+des)
# -                                                                                     13938
# Z92.2 - Historia personal de uso (presente) de otros medicamentos por largo tiempo       35
# I10 - Hipertensión esencial (primaria)                                                   23
# Z92.4 - Historia personal de cirugía mayor, no clasificada en otra parte                 21
# Z51.5 - Atención paliativa                                                               17
# Name: count, dtype: int64
#
# Diag 19 Secundario (cod+des):
# Diag 19 Secundario (cod+des)
# -                                                                                     14046
# Z92.2 - Historia personal de uso (presente) de otros medicamentos por largo tiempo       41
# Z92.4 - Historia personal de cirugía mayor, no clasificada en otra parte                 20
# I10 - Hipertensión esencial (primaria)                                                   19
# E11.9 - Diabetes mellitus tipo 2 sin complicaciones                                      11
# Name: count, dtype: int64
#
# Diag 20 Secundario (cod+des):
# Diag 20 Secundario (cod+des)
# -                                                                                                     14132
# Z92.2 - Historia personal de uso (presente) de otros medicamentos por largo tiempo                       31
# Z92.4 - Historia personal de cirugía mayor, no clasificada en otra parte                                 21
# F17.2 - Trastornos mentales y del comportamiento debidos al uso de tabaco, síndrome de dependencia       11
# I10 - Hipertensión esencial (primaria)                                                                   11
# Name: count, dtype: int64
#
# Diag 21 Secundario (cod+des):
# Diag 21 Secundario (cod+des)
# -                                                                                                     14208
# Z92.2 - Historia personal de uso (presente) de otros medicamentos por largo tiempo                       24
# I10 - Hipertensión esencial (primaria)                                                                   20
# F17.2 - Trastornos mentales y del comportamiento debidos al uso de tabaco, síndrome de dependencia        9
# Z92.1 - Historia personal de uso (presente) de anticoagulantes por largo tiempo                           8
# Name: count, dtype: int64
#
# Diag 22 Secundario (cod+des):
# Diag 22 Secundario (cod+des)
# -                                                                                     14257
# Z92.2 - Historia personal de uso (presente) de otros medicamentos por largo tiempo       24
# Z92.4 - Historia personal de cirugía mayor, no clasificada en otra parte                 13
# Z91.1 - Historia personal de incumplimiento del régimen o tratamiento médico              7
# D64.9 - Anemia de tipo no especificado                                                    6
# Name: count, dtype: int64
#
# Diag 23 Secundario (cod+des):
# Diag 23 Secundario (cod+des)
# -                                                                                     14308
# Z92.2 - Historia personal de uso (presente) de otros medicamentos por largo tiempo       15
# I10 - Hipertensión esencial (primaria)                                                   11
# Z92.4 - Historia personal de cirugía mayor, no clasificada en otra parte                 10
# Z51.5 - Atención paliativa                                                                8
# Name: count, dtype: int64
#
# Diag 24 Secundario (cod+des):
# Diag 24 Secundario (cod+des)
# -                                                                                     14346
# Z92.2 - Historia personal de uso (presente) de otros medicamentos por largo tiempo       18
# I10 - Hipertensión esencial (primaria)                                                   11
# Z92.4 - Historia personal de cirugía mayor, no clasificada en otra parte                  7
# L89.1 - Úlcera de decúbito estadío II                                                     6
# Name: count, dtype: int64
#
# Diag 25 Secundario (cod+des):
# Diag 25 Secundario (cod+des)
# -                                                                                     14367
# Z92.2 - Historia personal de uso (presente) de otros medicamentos por largo tiempo       10
# Z92.4 - Historia personal de cirugía mayor, no clasificada en otra parte                  9
# E87.1 - Hiposmolaridad e hiponatremia                                                     5
# I10 - Hipertensión esencial (primaria)                                                    5
# Name: count, dtype: int64
#
# Diag 26 Secundario (cod+des):
# Diag 26 Secundario (cod+des)
# -                                                                                     14407
# Z92.2 - Historia personal de uso (presente) de otros medicamentos por largo tiempo       13
# Z51.5 - Atención paliativa                                                                7
# E03.9 - Hipotiroidismo, no especificado                                                   6
# D64.9 - Anemia de tipo no especificado                                                    5
# Name: count, dtype: int64
#
# Diag 27 Secundario (cod+des):
# Diag 27 Secundario (cod+des)
# -                                                                                     14431
# Z92.4 - Historia personal de cirugía mayor, no clasificada en otra parte                  9
# Z92.2 - Historia personal de uso (presente) de otros medicamentos por largo tiempo        8
# Z02.7 - Extensión de certificado médico                                                   4
# B37.9 - Candidiasis, no especificada                                                      4
# Name: count, dtype: int64
#
# Diag 28 Secundario (cod+des):
# Diag 28 Secundario (cod+des)
# -                                                                                     14451
# Z92.2 - Historia personal de uso (presente) de otros medicamentos por largo tiempo       13
# L89.1 - Úlcera de decúbito estadío II                                                     4
# E87.5 - Hiperpotasemia                                                                    3
# Z51.5 - Atención paliativa                                                                3
# Name: count, dtype: int64
#
# Diag 29 Secundario (cod+des):
# Diag 29 Secundario (cod+des)
# -                                                                                     14468
# Z92.2 - Historia personal de uso (presente) de otros medicamentos por largo tiempo        5
# Z92.4 - Historia personal de cirugía mayor, no clasificada en otra parte                  4
# B37.9 - Candidiasis, no especificada                                                      4
# E11.9 - Diabetes mellitus tipo 2 sin complicaciones                                       3
# Name: count, dtype: int64
#
# Diag 30 Secundario (cod+des):
# Diag 30 Secundario (cod+des)
# -                                                                                     14485
# Z51.5 - Atención paliativa                                                                6
# Z92.2 - Historia personal de uso (presente) de otros medicamentos por largo tiempo        5
# I10 - Hipertensión esencial (primaria)                                                    3
# L89.9 - Úlcera de decúbito y area de presión no especificadas                             2
# Name: count, dtype: int64
#
# Diag 31 Secundario (cod+des):
# Diag 31 Secundario (cod+des)
# -                                                                                     14494
# B37.9 - Candidiasis, no especificada                                                      3
# Z92.2 - Historia personal de uso (presente) de otros medicamentos por largo tiempo        3
# Z92.4 - Historia personal de cirugía mayor, no clasificada en otra parte                  3
# Z02.7 - Extensión de certificado médico                                                   2
# Name: count, dtype: int64
#
# Diag 32 Secundario (cod+des):
# Diag 32 Secundario (cod+des)
# -                                                                                                     14504
# Z92.2 - Historia personal de uso (presente) de otros medicamentos por largo tiempo                        5
# L89.1 - Úlcera de decúbito estadío II                                                                     3
# Z02.7 - Extensión de certificado médico                                                                   2
# F17.2 - Trastornos mentales y del comportamiento debidos al uso de tabaco, síndrome de dependencia        2
# Name: count, dtype: int64
#
# Diag 33 Secundario (cod+des):
# Diag 33 Secundario (cod+des)
# -                                                                                         14518
# Z92.2 - Historia personal de uso (presente) de otros medicamentos por largo tiempo            3
# Z92.4 - Historia personal de cirugía mayor, no clasificada en otra parte                      2
# Z51.5 - Atención paliativa                                                                    2
# B95.7 - Otros estafilococos como causa de enfermedades clasificadas en otros capítulos        2
# Name: count, dtype: int64
#
# Diag 34 Secundario (cod+des):
# Diag 34 Secundario (cod+des)
# -                                                                                                     14521
# Z51.5 - Atención paliativa                                                                                3
# Z92.4 - Historia personal de cirugía mayor, no clasificada en otra parte                                  3
# F17.2 - Trastornos mentales y del comportamiento debidos al uso de tabaco, síndrome de dependencia        2
# Z95.5 - Presencia de angioplastia, injertos y prótesis coronarias                                         2
# Name: count, dtype: int64
#
# Diag 35 Secundario (cod+des):
# Diag 35 Secundario (cod+des)
# -                                                                                     14533
# Z92.2 - Historia personal de uso (presente) de otros medicamentos por largo tiempo        3
# Z75.3 - Problemas relacionados con atención de salud no disponible o inaccesible          2
# Z72.0 - Problemas relacionados con el uso del tabaco                                      1
# E66.9 - Obesidad, no especificada                                                         1
# Name: count, dtype: int64
#
# Proced 01 Principal (cod+des):
# Proced 01 Principal (cod+des)
# 73.59 - PARTO ASISTIDO MANUALMENTE.OTRO          1648
# 74.1 - CESAREA CERVICAL BAJA                     1214
# 87.03 - TOMOGRAFIA AXIAL COMPUTERIZADA CABEZA     981
# 87.44 - RADIOGRAFIA TORAX RUTINARIA               949
# 87.41 - TOMOGRAFIA AXIAL COMPUTERIZADA TORAX      738
# Name: count, dtype: int64
#
# Proced 02 Secundario (cod+des):
# Proced 02 Secundario (cod+des)
# 89.7 - EXAMEN FISICO GENERAL                               1404
# 75.69 - REPARACION DESGARRO OBSTETRICO ACTUAL OTRO.OTRO     891
# 90.59 - EXAMEN MICROSCOPICO SANGRE.OTRO                     855
# 88.01 - TOMOGRAFIA AXIAL COMPUTERIZADA ABDOMEN              838
# 87.44 - RADIOGRAFIA TORAX RUTINARIA                         500
# Name: count, dtype: int64
#
# Proced 03 Secundario (cod+des):
# Proced 03 Secundario (cod+des)
# 90.59 - EXAMEN MICROSCOPICO SANGRE.OTRO                        1892
# 89.7 - EXAMEN FISICO GENERAL                                   1107
# 99.18 - INYECCION ELECTROLITO                                   764
# 99.29 - INYECCION SUSTANCIA TERAPEUTICA O PROFILACTICA.OTRA     608
# 90.39 - EXAMEN MICROSCOPICO ORL.OTRO                            603
# Name: count, dtype: int64
#
# Proced 04 Secundario (cod+des):
# Proced 04 Secundario (cod+des)
# 90.59 - EXAMEN MICROSCOPICO SANGRE.OTRO                        1662
# 99.18 - INYECCION ELECTROLITO                                  1066
# 90.39 - EXAMEN MICROSCOPICO ORL.OTRO                            982
# 99.29 - INYECCION SUSTANCIA TERAPEUTICA O PROFILACTICA.OTRA     827
# 89.7 - EXAMEN FISICO GENERAL                                    736
# Name: count, dtype: int64
#
# Proced 05 Secundario (cod+des):
# Proced 05 Secundario (cod+des)
# 90.59 - EXAMEN MICROSCOPICO SANGRE.OTRO                        1641
# 90.39 - EXAMEN MICROSCOPICO ORL.OTRO                           1116
# 99.18 - INYECCION ELECTROLITO                                  1083
# 99.29 - INYECCION SUSTANCIA TERAPEUTICA O PROFILACTICA.OTRA    1031
# -                                                               962
# Name: count, dtype: int64
#
# Proced 06 Secundario (cod+des):
# Proced 06 Secundario (cod+des)
# -                                                              1480
# 90.59 - EXAMEN MICROSCOPICO SANGRE.OTRO                        1428
# 90.39 - EXAMEN MICROSCOPICO ORL.OTRO                           1193
# 99.29 - INYECCION SUSTANCIA TERAPEUTICA O PROFILACTICA.OTRA    1082
# 99.18 - INYECCION ELECTROLITO                                   870
# Name: count, dtype: int64
#
# Proced 07 Secundario (cod+des):
# Proced 07 Secundario (cod+des)
# -                                                              2135
# 90.59 - EXAMEN MICROSCOPICO SANGRE.OTRO                        1102
# 90.39 - EXAMEN MICROSCOPICO ORL.OTRO                           1098
# 99.18 - INYECCION ELECTROLITO                                  1047
# 99.29 - INYECCION SUSTANCIA TERAPEUTICA O PROFILACTICA.OTRA    1040
# Name: count, dtype: int64
#
# Proced 08 Secundario (cod+des):
# Proced 08 Secundario (cod+des)
# -                                                              3012
# 99.29 - INYECCION SUSTANCIA TERAPEUTICA O PROFILACTICA.OTRA    1098
# 90.39 - EXAMEN MICROSCOPICO ORL.OTRO                            951
# 99.18 - INYECCION ELECTROLITO                                   830
# 90.59 - EXAMEN MICROSCOPICO SANGRE.OTRO                         811
# Name: count, dtype: int64
#
# Proced 09 Secundario (cod+des):
# Proced 09 Secundario (cod+des)
# -                                                              3937
# 99.29 - INYECCION SUSTANCIA TERAPEUTICA O PROFILACTICA.OTRA     967
# 90.39 - EXAMEN MICROSCOPICO ORL.OTRO                            854
# 90.59 - EXAMEN MICROSCOPICO SANGRE.OTRO                         820
# 89.7 - EXAMEN FISICO GENERAL                                    700
# Name: count, dtype: int64
#
# Proced 10 Secundario (cod+des):
# Proced 10 Secundario (cod+des)
# -                                                              4982
# 99.29 - INYECCION SUSTANCIA TERAPEUTICA O PROFILACTICA.OTRA     763
# 89.7 - EXAMEN FISICO GENERAL                                    737
# 90.39 - EXAMEN MICROSCOPICO ORL.OTRO                            700
# 90.59 - EXAMEN MICROSCOPICO SANGRE.OTRO                         525
# Name: count, dtype: int64
#
# Proced 11 Secundario (cod+des):
# Proced 11 Secundario (cod+des)
# -                                                              6091
# 89.7 - EXAMEN FISICO GENERAL                                    715
# 99.29 - INYECCION SUSTANCIA TERAPEUTICA O PROFILACTICA.OTRA     600
# 90.39 - EXAMEN MICROSCOPICO ORL.OTRO                            572
# 89.26 - EXAMEN GINECOLOGICO                                     430
# Name: count, dtype: int64
#
# Proced 12 Secundario (cod+des):
# Proced 12 Secundario (cod+des)
# -                                                              7341
# 89.7 - EXAMEN FISICO GENERAL                                    632
# 90.39 - EXAMEN MICROSCOPICO ORL.OTRO                            438
# 99.29 - INYECCION SUSTANCIA TERAPEUTICA O PROFILACTICA.OTRA     390
# 89.26 - EXAMEN GINECOLOGICO                                     339
# Name: count, dtype: int64
#
# Proced 13 Secundario (cod+des):
# Proced 13 Secundario (cod+des)
# -                                                              8446
# 89.7 - EXAMEN FISICO GENERAL                                    514
# 90.39 - EXAMEN MICROSCOPICO ORL.OTRO                            325
# 93.82 - TERAPIA EDUCATIVA                                       296
# 99.29 - INYECCION SUSTANCIA TERAPEUTICA O PROFILACTICA.OTRA     281
# Name: count, dtype: int64
#
# Proced 14 Secundario (cod+des):
# Proced 14 Secundario (cod+des)
# -                                       9359
# 89.7 - EXAMEN FISICO GENERAL             405
# 90.39 - EXAMEN MICROSCOPICO ORL.OTRO     295
# 93.82 - TERAPIA EDUCATIVA                259
# 93.01 - EVALUACION FUNCIONAL             204
# Name: count, dtype: int64
#
# Proced 15 Secundario (cod+des):
# Proced 15 Secundario (cod+des)
# -                                 10111
# 89.7 - EXAMEN FISICO GENERAL        348
# 93.82 - TERAPIA EDUCATIVA           216
# 93.18 - EJERCICIO RESPIRATORIO      189
# 93.01 - EVALUACION FUNCIONAL        174
# Name: count, dtype: int64
#
# Proced 16 Secundario (cod+des):
# Proced 16 Secundario (cod+des)
# -                                                              10667
# 89.7 - EXAMEN FISICO GENERAL                                     269
# 93.18 - EJERCICIO RESPIRATORIO                                   196
# 93.82 - TERAPIA EDUCATIVA                                        186
# 99.29 - INYECCION SUSTANCIA TERAPEUTICA O PROFILACTICA.OTRA      161
# Name: count, dtype: int64
#
# Proced 17 Secundario (cod+des):
# Proced 17 Secundario (cod+des)
# -                                      11076
# 89.7 - EXAMEN FISICO GENERAL             191
# 93.82 - TERAPIA EDUCATIVA                165
# 93.18 - EJERCICIO RESPIRATORIO           158
# 93.19 - EJERCICIO FISIOTERAPIA NCOC      147
# Name: count, dtype: int64
#
# Proced 18 Secundario (cod+des):
# Proced 18 Secundario (cod+des)
# -                                    11391
# 89.7 - EXAMEN FISICO GENERAL           187
# 93.18 - EJERCICIO RESPIRATORIO         151
# 93.99 - TERAPIA RESPIRATORIA.OTRA      144
# 93.82 - TERAPIA EDUCATIVA              142
# Name: count, dtype: int64
#
# Proced 19 Secundario (cod+des):
# Proced 19 Secundario (cod+des)
# -                                      11667
# 89.7 - EXAMEN FISICO GENERAL             157
# 93.18 - EJERCICIO RESPIRATORIO           140
# 93.19 - EJERCICIO FISIOTERAPIA NCOC      136
# 93.99 - TERAPIA RESPIRATORIA.OTRA        129
# Name: count, dtype: int64
#
# Proced 20 Secundario (cod+des):
# Proced 20 Secundario (cod+des)
# -                                      11913
# 93.19 - EJERCICIO FISIOTERAPIA NCOC      132
# 93.99 - TERAPIA RESPIRATORIA.OTRA        130
# 93.82 - TERAPIA EDUCATIVA                128
# 89.7 - EXAMEN FISICO GENERAL             124
# Name: count, dtype: int64
#
# Proced 21 Secundario (cod+des):
# Proced 21 Secundario (cod+des)
# -                                    12120
# 93.18 - EJERCICIO RESPIRATORIO         146
# 89.7 - EXAMEN FISICO GENERAL           133
# 93.82 - TERAPIA EDUCATIVA              112
# 93.99 - TERAPIA RESPIRATORIA.OTRA      112
# Name: count, dtype: int64
#
# Proced 22 Secundario (cod+des):
# Proced 22 Secundario (cod+des)
# -                                      12321
# 93.18 - EJERCICIO RESPIRATORIO           121
# 93.99 - TERAPIA RESPIRATORIA.OTRA        118
# 93.19 - EJERCICIO FISIOTERAPIA NCOC      117
# 89.7 - EXAMEN FISICO GENERAL             104
# Name: count, dtype: int64
#
# Proced 23 Secundario (cod+des):
# Proced 23 Secundario (cod+des)
# -                                      12496
# 93.19 - EJERCICIO FISIOTERAPIA NCOC      112
# 89.7 - EXAMEN FISICO GENERAL             106
# 93.18 - EJERCICIO RESPIRATORIO           105
# 93.82 - TERAPIA EDUCATIVA                100
# Name: count, dtype: int64
#
# Proced 24 Secundario (cod+des):
# Proced 24 Secundario (cod+des)
# -                                                12666
# 89.7 - EXAMEN FISICO GENERAL                       120
# 93.99 - TERAPIA RESPIRATORIA.OTRA                   95
# 93.19 - EJERCICIO FISIOTERAPIA NCOC                 83
# 93.14 - ENTRENAMIENTO MOVIMIENTO ARTICULACION       80
# Name: count, dtype: int64
#
# Proced 25 Secundario (cod+des):
# Proced 25 Secundario (cod+des)
# -                                        12851
# 93.99 - TERAPIA RESPIRATORIA.OTRA           99
# 89.7 - EXAMEN FISICO GENERAL                84
# 93.27 - ESTIRAMIENTO MUSCULO Y TENDON       82
# 93.18 - EJERCICIO RESPIRATORIO              80
# Name: count, dtype: int64
#
# Proced 26 Secundario (cod+des):
# Proced 26 Secundario (cod+des)
# -                                      12989
# 89.7 - EXAMEN FISICO GENERAL              95
# 93.82 - TERAPIA EDUCATIVA                 93
# 93.99 - TERAPIA RESPIRATORIA.OTRA         79
# 93.19 - EJERCICIO FISIOTERAPIA NCOC       66
# Name: count, dtype: int64
#
# Proced 27 Secundario (cod+des):
# Proced 27 Secundario (cod+des)
# -                                      13138
# 89.7 - EXAMEN FISICO GENERAL              86
# 93.82 - TERAPIA EDUCATIVA                 68
# 93.19 - EJERCICIO FISIOTERAPIA NCOC       64
# 93.99 - TERAPIA RESPIRATORIA.OTRA         64
# Name: count, dtype: int64
#
# Proced 28 Secundario (cod+des):
# Proced 28 Secundario (cod+des)
# -                                        13261
# 89.7 - EXAMEN FISICO GENERAL                80
# 93.99 - TERAPIA RESPIRATORIA.OTRA           67
# 93.18 - EJERCICIO RESPIRATORIO              59
# 93.27 - ESTIRAMIENTO MUSCULO Y TENDON       54
# Name: count, dtype: int64
#
# Proced 29 Secundario (cod+des):
# Proced 29 Secundario (cod+des)
# -                                        13379
# 89.7 - EXAMEN FISICO GENERAL                67
# 93.99 - TERAPIA RESPIRATORIA.OTRA           59
# 93.82 - TERAPIA EDUCATIVA                   59
# 93.27 - ESTIRAMIENTO MUSCULO Y TENDON       47
# Name: count, dtype: int64
#
# Proced 30 Secundario (cod+des):
# Proced 30 Secundario (cod+des)
# -                                                13498
# 89.7 - EXAMEN FISICO GENERAL                        61
# 93.99 - TERAPIA RESPIRATORIA.OTRA                   58
# 93.14 - ENTRENAMIENTO MOVIMIENTO ARTICULACION       47
# 93.18 - EJERCICIO RESPIRATORIO                      45
# Name: count, dtype: int64
#
# Sexo (Desc):
# Sexo (Desc)
# Mujer     9617
# Hombre    4944
# Name: count, dtype: int64
#
# GRD:
# GRD
# 146101 - PH CESÁREA                                                                       813
# 146121 - PH PARTO VAGINAL CON PROCED., EXCEPTO ESTERILIZACIÓN Y/O DILATACIÓN Y LEGRADO    639
# 146131 - PH PARTO VAGINAL                                                                 538
# 158171 - MH NEONATO, PESO AL NACER >2499 GR SIN PROCEDIMIENTO MAYOR                       389
# 134161 - MH TRASTORNOS DEL ANTEPARTO                                                      325
# Name: count, dtype: int64

# %%
df['GRD'].value_counts()
df_capitulo = df.copy()
df_capitulo["Diag 01 Principal (cod+des)"] = (
    df_capitulo["Diag 01 Principal (cod+des)"]
    .str.split(" - ").str[0]   # A41.8
    .str[0]                    # A
)
df_capitulo
# Out:
#       Diag 01 Principal (cod+des)  \
# 0                               A
# 1                               U
# 2                               K
# 3                               K
# 4                               T
# ...                           ...
# 14556                           E
# 14557                           S
# 14558                           K
# 14559                           E
# 14560                           S
#
#                             Diag 02 Secundario (cod+des)  \
# 0         B37.6 - Endocarditis debida a candida (I39.8*)
# 1                  J12.8 - Neumonía debida a otros virus
# 2                                  R57.2 - Shock séptico
# 3                                  K66.1 - Hemoperitoneo
# 4      Y83.2 - Operación quirúrgica con anastomosis, ...
# ...                                                  ...
# 14556                      J45.9 - Asma, no especificada
# 14557  W18.24 - Otras caídas en el mismo nivel, escue...
# 14558             I10 - Hipertensión esencial (primaria)
# 14559             I10 - Hipertensión esencial (primaria)
# 14560  S06.21 - Traumatismo cerebral difuso, con heri...
#
#                             Diag 03 Secundario (cod+des)  \
# 0      I39.8 - Endocarditis, válvula no especificada,...
# 1                                         R06.0 - Disnea
# 2                            R57.1 - Choque hipovolémico
# 3            N18.5 - Enfermedad renal crónica, estadio 5
# 4                   S31.1 - Herida de la pared abdominal
# ...                                                  ...
# 14556  F10.2 - Trastornos mentales y del comportamien...
# 14557                            R55 - Síncope y colapso
# 14558  E11.9 - Diabetes mellitus tipo 2 sin complicac...
# 14559  Z92.2 - Historia personal de uso (presente) de...
# 14560  W18.09 - Otras caídas en el mismo nivel, vivie...
#
#                             Diag 04 Secundario (cod+des)  \
# 0                N10 - Nefritis tubulointersticial aguda
# 1                                              R05 - Tos
# 2      J80 - Síndrome de dificultad respiratoria del ...
# 3                 D64.9 - Anemia de tipo no especificado
# 4      S36.80 - Traumatismo de otros órganos intraabd...
# ...                                                  ...
# 14556  F17.2 - Trastornos mentales y del comportamien...
# 14557                                                  -
# 14558    I50.9 - Insuficiencia cardíaca, no especificada
# 14559                                                  -
# 14560  J69.0 - Neumonitis debida a aspiración de alim...
#
#                             Diag 05 Secundario (cod+des)  \
# 0      B96.1 - Klebsiella pneumoniae [K. pneumoniae] ...
# 1                        R50.9 - Fiebre, no especificada
# 2                              Y95 - Afección nosocomial
# 3                                 E87.5 - Hiperpotasemia
# 4      W31.62 - Contacto traumático con otras maquina...
# ...                                                  ...
# 14556  Z91.1 - Historia personal de incumplimiento de...
# 14557                                                  -
# 14558  K25.9 - Úlcera gástrica, no especificada como ...
# 14559                                                  -
# 14560               D29.1 - Tumor benigno de la próstata
#
#                             Diag 06 Secundario (cod+des)  \
# 0      L89.9 - Úlcera de decúbito y area de presión n...
# 1                                    Z29.0 - Aislamiento
# 2        J15.0 - Neumonía debida a Klebsiella pneumoniae
# 3                                       E87.2 - Acidosis
# 4      J96.09 - Insuficiencia respiratoria aguda, Tip...
# ...                                                  ...
# 14556                                                  -
# 14557                                                  -
# 14558               M16.9 - Coxartrosis, no especificada
# 14559                                                  -
# 14560  Z59.0 - Problemas relacionados con la falta de...
#
#                             Diag 07 Secundario (cod+des)  \
# 0      L08.9 - Infección local de la piel y del tejid...
# 1                          Z01.7 - Examen de laboratorio
# 2      U82.2 - Resistencia a Betalactamasas de amplio...
# 3                                   J81 - Edema pulmonar
# 4        J15.0 - Neumonía debida a Klebsiella pneumoniae
# ...                                                  ...
# 14556                                                  -
# 14557                                                  -
# 14558                            G47.3 - Apnea del sueño
# 14559                                                  -
# 14560            Z02.7 - Extensión de certificado médico
#
#                             Diag 08 Secundario (cod+des)  \
# 0      B96.2 - Escherichia coli [E. coli] como causa ...
# 1      J96.00 - Insuficiencia respiratoria aguda, Tip...
# 2      B95.6 - Staphylococcus aureus como causa de en...
# 3            N17.8 - Otras insuficiencias renales agudas
# 4      U82.2 - Resistencia a Betalactamasas de amplio...
# ...                                                  ...
# 14556                                                  -
# 14557                                                  -
# 14558  Z99.8 - Dependencia de otras máquinas y dispos...
# 14559                                                  -
# 14560                                                  -
#
#                             Diag 09 Secundario (cod+des)  \
# 0      A41.5 - Sepsis por otros organnismos Gram nega...
# 1                                      J94.2 - Hemotórax
# 2      B96.8 - Otros agentes bacterianos especificado...
# 3      J44.9 - Enfermedad pulmonar obstructiva crónic...
# 4                   U07.1 - COVID-19, virus identificado
# ...                                                  ...
# 14556                                                  -
# 14557                                                  -
# 14558                                                  -
# 14559                                                  -
# 14560                                                  -
#
#                             Diag 10 Secundario (cod+des)  ...  \
# 0                           J86.9 - Piotórax sin fístula  ...
# 1                  J92.9 - Paquipleuritis sin asbestosis  ...
# 2                           B37.1 - Candidiasis pulmonar  ...
# 3                 R41.0 - Desorientación no especificada  ...
# 4      N39.0 - Infección de vías urinarias, sitio no ...  ...
# ...                                                  ...  ...
# 14556                                                  -  ...
# 14557                                                  -  ...
# 14558                                                  -  ...
# 14559                                                  -  ...
# 14560                                                  -  ...
#
#                    Proced 24 Secundario (cod+des)  \
# 0                             99.84 - AISLAMIENTO
# 1        91.62 - EXAMEN MICROSCOPICO PIEL.CULTIVO
# 2                             99.84 - AISLAMIENTO
# 3             57.94 - SONDAJE URINARIO PERMANENTE
# 4      90.52 - EXAMEN MICROSCOPICO SANGRE.CULTIVO
# ...                                           ...
# 14556                                           -
# 14557                                           -
# 14558                                           -
# 14559                                           -
# 14560                     89.66 - GASOMETRIA VENA
#
#                           Proced 25 Secundario (cod+des)  \
# 0                                88.72 - ECOCARDIOGRAFIA
# 1      90.43 - EXAMEN MICROSCOPICO RESPIRATORIO.CULTI...
# 2      91.73 - EXAMEN MICROSCOPICO HERIDA OPERATORIA....
# 3                           00.13 - INYECCION NESIRITIDE
# 4      91.39 - EXAMEN MICROSCOPICO URINARIO INFERIOR....
# ...                                                  ...
# 14556                                                  -
# 14557                                                  -
# 14558                                                  -
# 14559                                                  -
# 14560                            89.66 - GASOMETRIA VENA
#
#                           Proced 26 Secundario (cod+des)  \
# 0       90.42 - EXAMEN MICROSCOPICO RESPIRATORIO.CULTIVO
# 1      91.39 - EXAMEN MICROSCOPICO URINARIO INFERIOR....
# 2      90.53 - EXAMEN MICROSCOPICO SANGRE.CULTIVO Y S...
# 3                      00.17 - INFUSON AGENTE VASOPRESOR
# 4      91.32 - EXAMEN MICROSCOPICO URINARIO INFERIOR....
# ...                                                  ...
# 14556                                                  -
# 14557                                                  -
# 14558                                                  -
# 14559                                                  -
# 14560               90.39 - EXAMEN MICROSCOPICO ORL.OTRO
#
#                           Proced 27 Secundario (cod+des)  \
# 0             90.52 - EXAMEN MICROSCOPICO SANGRE.CULTIVO
# 1             90.52 - EXAMEN MICROSCOPICO SANGRE.CULTIVO
# 2                       99.26 - INYECCION TRANQUILIZANTE
# 3               99.04 - TRANSFUSION CONCENTRADO HEMATIES
# 4      93.90 - RESPIRACION PRESION POSITIVA CONTINUA ...
# ...                                                  ...
# 14556                                                  -
# 14557                                                  -
# 14558                                                  -
# 14559                                                  -
# 14560   90.42 - EXAMEN MICROSCOPICO RESPIRATORIO.CULTIVO
#
#                           Proced 28 Secundario (cod+des)  \
# 0      91.39 - EXAMEN MICROSCOPICO URINARIO INFERIOR....
# 1      91.32 - EXAMEN MICROSCOPICO URINARIO INFERIOR....
# 2      89.39 - OTRAS MEDICIONES Y EXAMENES NO QUIRURG...
# 3                          99.18 - INYECCION ELECTROLITO
# 4      99.15 - INFUSION PARENTERAL SUSTANCIA NUTRITIV...
# ...                                                  ...
# 14556                                                  -
# 14557                                                  -
# 14558                                                  -
# 14559                                                  -
# 14560         90.52 - EXAMEN MICROSCOPICO SANGRE.CULTIVO
#
#                           Proced 29 Secundario (cod+des)  \
# 0      91.33 - EXAMEN MICROSCOPICO URINARIO INFERIOR....
# 1                         96.59 - IRRIGACION HERIDA OTRA
# 2                                89.66 - GASOMETRIA VENA
# 3                          99.21 - INYECCION ANTIBIOTICO
# 4                         96.59 - IRRIGACION HERIDA OTRA
# ...                                                  ...
# 14556                                                  -
# 14557                                                  -
# 14558                                                  -
# 14559                                                  -
# 14560            90.59 - EXAMEN MICROSCOPICO SANGRE.OTRO
#
#                           Proced 30 Secundario (cod+des) Edad en años  \
# 0          87.03 - TOMOGRAFIA AXIAL COMPUTERIZADA CABEZA           40
# 1      90.99 - EXAMEN MICROSCOPICO DIGESTIVO INFERIOR...           53
# 2                             89.65 - GASOMETRIA ARTERIA           65
# 3                            99.23 - INYECCION ESTEROIDE           61
# 4               45.13 - ESOFAGOGASTRODUODENOSCOPIA [EGD]           30
# ...                                                  ...          ...
# 14556                                                  -           26
# 14557                                                  -           10
# 14558                                                  -           58
# 14559                                                  -           47
# 14560            90.59 - EXAMEN MICROSCOPICO SANGRE.OTRO           73
#
#       Sexo (Desc)                                                GRD
# 0          Hombre                       184103 - MH SEPTICEMIA W/MCC
# 1          Hombre  041013 - PH ECMO VENTILACIÓN MECÁNICA PROLONGA...
# 2          Hombre  041013 - PH ECMO VENTILACIÓN MECÁNICA PROLONGA...
# 3          Hombre  041023 - PH VENTILACIÓN MECÁNICA PROLONGADA SI...
# 4          Hombre  041023 - PH VENTILACIÓN MECÁNICA PROLONGADA SI...
# ...           ...                                                ...
# 14556       Mujer  104101 - MH DIABETES Y ENFERMEDADES METABÓLICA...
# 14557      Hombre              014242 - MH TRAUMATISMO CEFÁLICO W/CC
# 14558      Hombre  064182 - MH OTROS DIAGNÓSTICOS SOBRE APARATO D...
# 14559      Hombre      104121 - MH ERRORES CONGÉNITOS DE METABOLISMO
# 14560      Hombre  041203 - PH PROCEDIMIENTOS NO COMPLEJOS SOBRE ...
#
# [14561 rows x 68 columns]

# %%
df_categoria = df.copy()


df_categoria["Diag 01 Principal (cod+des)"] = (
    df_categoria["Diag 01 Principal (cod+des)"]
    .str.split(" - ").str[0]   # A41.8
    .str[:3]                   # A41
)
df_categoria

col_diag = [c for c in df.columns if 'Diag' in c and "(cod+des)"in c]
col_proc= [c for c in df.columns if 'Proced' in c and "(cod+des)"in c]

for col in col_proc:
    df_categoria[col] = (
                        df_categoria[col].fillna('').astype(str)
                        .str.split(" - ").str[0].str[:2]
                        )
for col in col_diag:
    df_categoria[col] = (
        df_categoria[col].str.split(" - ").str[0].str[:3]
    )
df_categoria
df_categoria['Sexo (Desc)'].unique()
df_categoria['Sexo (Desc)'] = df_categoria['Sexo (Desc)'].map({'Hombre': 1, 'Mujer': 0})
df_categoria

df_categoria.to_csv('../data/processed/elpino_categories.csv', index=False)

# %%
eda.summaryEda(df_categoria, 'GRD')
# Out:
# Tipos de datos:
#                                   tipo
# Diag 01 Principal (cod+des)     object
# Diag 02 Secundario (cod+des)    object
# Diag 03 Secundario (cod+des)    object
# Diag 04 Secundario (cod+des)    object
# Diag 05 Secundario (cod+des)    object
# ...                                ...
# Proced 29 Secundario (cod+des)  object
# Proced 30 Secundario (cod+des)  object
# Edad en años                     int64
# Sexo (Desc)                      int64
# GRD                             object
#
# [68 rows x 1 columns]
#  Valores faltantes por columna
#                                 Valores faltantes
# Diag 01 Principal (cod+des)                     0
# Diag 02 Secundario (cod+des)                    0
# Diag 03 Secundario (cod+des)                    0
# Diag 04 Secundario (cod+des)                    0
# Diag 05 Secundario (cod+des)                    0
# ...                                           ...
# Proced 29 Secundario (cod+des)                  0
# Proced 30 Secundario (cod+des)                  0
# Edad en años                                    0
# Sexo (Desc)                                     0
# GRD                                             0
#
# [68 rows x 1 columns]
# Variables con alta cardinalidad ( > 100 categorías):
#                               Unique_Values
# Diag 02 Secundario (cod+des)            845
# Diag 03 Secundario (cod+des)            779
# Diag 04 Secundario (cod+des)            712
# Diag 01 Principal (cod+des)             687
# Diag 05 Secundario (cod+des)            647
# Diag 06 Secundario (cod+des)            561
# GRD                                     526
# Diag 07 Secundario (cod+des)            499
# Diag 08 Secundario (cod+des)            454
# Diag 09 Secundario (cod+des)            407
# Diag 10 Secundario (cod+des)            362
# Diag 11 Secundario (cod+des)            353
# Diag 12 Secundario (cod+des)            321
# Diag 13 Secundario (cod+des)            273
# Diag 14 Secundario (cod+des)            249
# Diag 15 Secundario (cod+des)            227
# Diag 16 Secundario (cod+des)            207
# Diag 17 Secundario (cod+des)            203
# Diag 18 Secundario (cod+des)            185
# Diag 19 Secundario (cod+des)            152
# Diag 20 Secundario (cod+des)            137
# Diag 21 Secundario (cod+des)            131
# Diag 22 Secundario (cod+des)            122
# Diag 23 Secundario (cod+des)            102
#  Estadística descriptiva
#                                   count unique                  top   freq  \
# Diag 01 Principal (cod+des)       14561    687                  O70    864
# Diag 02 Secundario (cod+des)      14561    845                    -   1209
# Diag 03 Secundario (cod+des)      14561    779                    -   2687
# Diag 04 Secundario (cod+des)      14561    712                    -   4127
# Diag 05 Secundario (cod+des)      14561    647                    -   5371
# ...                                 ...    ...                  ...    ...
# Proced 29 Secundario (cod+des)    14561     19                    -  13379
# Proced 30 Secundario (cod+des)    14561     18                    -  13498
# Edad en años                    14561.0    NaN                  NaN    NaN
# Sexo (Desc)                     14561.0    NaN                  NaN    NaN
# GRD                               14561    526  146101 - PH CESÁREA    813
#
#                                     mean        std  min   25%   50%   75%  \
# Diag 01 Principal (cod+des)          NaN        NaN  NaN   NaN   NaN   NaN
# Diag 02 Secundario (cod+des)         NaN        NaN  NaN   NaN   NaN   NaN
# Diag 03 Secundario (cod+des)         NaN        NaN  NaN   NaN   NaN   NaN
# Diag 04 Secundario (cod+des)         NaN        NaN  NaN   NaN   NaN   NaN
# Diag 05 Secundario (cod+des)         NaN        NaN  NaN   NaN   NaN   NaN
# ...                                  ...        ...  ...   ...   ...   ...
# Proced 29 Secundario (cod+des)       NaN        NaN  NaN   NaN   NaN   NaN
# Proced 30 Secundario (cod+des)       NaN        NaN  NaN   NaN   NaN   NaN
# Edad en años                    39.42655  24.681545  0.0  23.0  36.0  60.0
# Sexo (Desc)                     0.339537   0.473568  0.0   0.0   0.0   1.0
# GRD                                  NaN        NaN  NaN   NaN   NaN   NaN
#
#                                   max
# Diag 01 Principal (cod+des)       NaN
# Diag 02 Secundario (cod+des)      NaN
# Diag 03 Secundario (cod+des)      NaN
# Diag 04 Secundario (cod+des)      NaN
# Diag 05 Secundario (cod+des)      NaN
# ...                               ...
# Proced 29 Secundario (cod+des)    NaN
# Proced 30 Secundario (cod+des)    NaN
# Edad en años                    121.0
# Sexo (Desc)                       1.0
# GRD                               NaN
#
# [68 rows x 11 columns]
# Distribución de la variable objetivo:
#                                                     conteo
# GRD
# 146101 - PH CESÁREA                                    813
# 146121 - PH PARTO VAGINAL CON PROCED., EXCEPTO ...     639
# 146131 - PH PARTO VAGINAL                              538
# 158171 - MH NEONATO, PESO AL NACER >2499 GR SIN...     389
# 134161 - MH TRASTORNOS DEL ANTEPARTO                   325
# ...                                                    ...
# 214103 - MH LESIONES DE MÚLTIPLES SITIOS NO ESP...       1
# 054223 - MH MIOCARDIOPATÍA W/MCC                         1
# 114142 - MH DISFUNCIÓN, REACCIÓN O COMPL. POR D...       1
# 131122 - PH INTERRUPCIÓN TUBÁRICA ABIERTA W/CC           1
# 134153 - MH FALSO TRABAJO DEL PARTO W/MCC                1
#
# [526 rows x 1 columns]
# Columnas categóricas - Top 5 valores:
#
# Diag 01 Principal (cod+des):
# Diag 01 Principal (cod+des)
# O70    864
# O80    471
# K80    471
# U07    395
# O34    344
# Name: count, dtype: int64
#
# Diag 02 Secundario (cod+des):
# Diag 02 Secundario (cod+des)
# -      1209
# I10     828
# O80     704
# O82     578
# J96     533
# Name: count, dtype: int64
#
# Diag 03 Secundario (cod+des):
# Diag 03 Secundario (cod+des)
# -      2687
# I10     664
# O99     519
# Z37     497
# E11     426
# Name: count, dtype: int64
#
# Diag 04 Secundario (cod+des):
# Diag 04 Secundario (cod+des)
# -      4127
# Z37     527
# O99     501
# Z38     497
# I10     477
# Name: count, dtype: int64
#
# Diag 05 Secundario (cod+des):
# Diag 05 Secundario (cod+des)
# -      5371
# Z39     630
# Z37     535
# Z38     531
# Z92     421
# Name: count, dtype: int64
#
# Diag 06 Secundario (cod+des):
# Diag 06 Secundario (cod+des)
# -      6394
# Z39    1157
# Z38     537
# Z92     440
# Z37     437
# Name: count, dtype: int64
#
# Diag 07 Secundario (cod+des):
# Diag 07 Secundario (cod+des)
# -      7408
# Z39    1564
# Z92     449
# Z38     437
# Z37     339
# Name: count, dtype: int64
#
# Diag 08 Secundario (cod+des):
# Diag 08 Secundario (cod+des)
# -      8584
# Z39    1504
# Z92     387
# Z38     336
# Z37     218
# Name: count, dtype: int64
#
# Diag 09 Secundario (cod+des):
# Diag 09 Secundario (cod+des)
# -      9719
# Z39    1312
# Z92     299
# Z38     216
# E87     146
# Name: count, dtype: int64
#
# Diag 10 Secundario (cod+des):
# Diag 10 Secundario (cod+des)
# -      10696
# Z39      987
# Z92      306
# I10      128
# Z38      110
# Name: count, dtype: int64
#
# Diag 11 Secundario (cod+des):
# Diag 11 Secundario (cod+des)
# -      11574
# Z39      660
# Z92      215
# E87       96
# I10       85
# Name: count, dtype: int64
#
# Diag 12 Secundario (cod+des):
# Diag 12 Secundario (cod+des)
# -      12238
# Z39      380
# Z92      191
# E87       84
# I10       72
# Name: count, dtype: int64
#
# Diag 13 Secundario (cod+des):
# Diag 13 Secundario (cod+des)
# -      12761
# Z39      201
# Z92      167
# E87       82
# I10       63
# Name: count, dtype: int64
#
# Diag 14 Secundario (cod+des):
# Diag 14 Secundario (cod+des)
# -      13130
# Z92      133
# Z39      108
# E87       64
# I10       50
# Name: count, dtype: int64
#
# Diag 15 Secundario (cod+des):
# Diag 15 Secundario (cod+des)
# -      13423
# Z92      122
# Z39       60
# E87       43
# I10       32
# Name: count, dtype: int64
#
# Diag 16 Secundario (cod+des):
# Diag 16 Secundario (cod+des)
# -      13638
# Z92      100
# E87       38
# I10       34
# Z39       32
# Name: count, dtype: int64
#
# Diag 17 Secundario (cod+des):
# Diag 17 Secundario (cod+des)
# -      13802
# Z92       84
# E87       32
# I10       25
# E11       24
# Name: count, dtype: int64
#
# Diag 18 Secundario (cod+des):
# Diag 18 Secundario (cod+des)
# -      13938
# Z92       66
# E87       32
# I10       23
# E11       20
# Name: count, dtype: int64
#
# Diag 19 Secundario (cod+des):
# Diag 19 Secundario (cod+des)
# -      14046
# Z92       70
# E87       23
# L89       19
# I10       19
# Name: count, dtype: int64
#
# Diag 20 Secundario (cod+des):
# Diag 20 Secundario (cod+des)
# -      14132
# Z92       56
# E87       19
# Z86       15
# E11       14
# Name: count, dtype: int64
#
# Diag 21 Secundario (cod+des):
# Diag 21 Secundario (cod+des)
# -      14208
# Z92       39
# I10       20
# Z90       12
# L89       12
# Name: count, dtype: int64
#
# Diag 22 Secundario (cod+des):
# Diag 22 Secundario (cod+des)
# -      14257
# Z92       41
# E87       11
# Z91        9
# Z88        7
# Name: count, dtype: int64
#
# Diag 23 Secundario (cod+des):
# Diag 23 Secundario (cod+des)
# -      14308
# Z92       33
# E87       12
# I10       11
# Z86        9
# Name: count, dtype: int64
#
# Diag 24 Secundario (cod+des):
# Diag 24 Secundario (cod+des)
# -      14346
# Z92       27
# I10       11
# E87       10
# L89        8
# Name: count, dtype: int64
#
# Diag 25 Secundario (cod+des):
# Diag 25 Secundario (cod+des)
# -      14367
# Z92       23
# E87        7
# B96        6
# Z02        5
# Name: count, dtype: int64
#
# Diag 26 Secundario (cod+des):
# Diag 26 Secundario (cod+des)
# -      14407
# Z92       20
# Z51        7
# E03        6
# L89        6
# Name: count, dtype: int64
#
# Diag 27 Secundario (cod+des):
# Diag 27 Secundario (cod+des)
# -      14431
# Z92       20
# E87        5
# Z02        4
# Z95        4
# Name: count, dtype: int64
#
# Diag 28 Secundario (cod+des):
# Diag 28 Secundario (cod+des)
# -      14451
# Z92       16
# E87        6
# Z91        4
# L89        4
# Name: count, dtype: int64
#
# Diag 29 Secundario (cod+des):
# Diag 29 Secundario (cod+des)
# -      14468
# Z92       11
# B37        4
# E87        4
# E11        4
# Name: count, dtype: int64
#
# Diag 30 Secundario (cod+des):
# Diag 30 Secundario (cod+des)
# -      14485
# Z92        7
# Z51        6
# E87        3
# L89        3
# Name: count, dtype: int64
#
# Diag 31 Secundario (cod+des):
# Diag 31 Secundario (cod+des)
# -      14494
# Z92        6
# F05        3
# L89        3
# B37        3
# Name: count, dtype: int64
#
# Diag 32 Secundario (cod+des):
# Diag 32 Secundario (cod+des)
# -      14504
# Z92        8
# L89        3
# Z59        3
# E87        3
# Name: count, dtype: int64
#
# Diag 33 Secundario (cod+des):
# Diag 33 Secundario (cod+des)
# -      14518
# Z92        6
# B95        3
# Z89        2
# Z51        2
# Name: count, dtype: int64
#
# Diag 34 Secundario (cod+des):
# Diag 34 Secundario (cod+des)
# -      14521
# Z92        5
# Z51        3
# B96        3
# Z85        2
# Name: count, dtype: int64
#
# Diag 35 Secundario (cod+des):
# Diag 35 Secundario (cod+des)
# -      14533
# Z92        4
# Z72        2
# E66        2
# L89        2
# Name: count, dtype: int64
#
# Proced 01 Principal (cod+des):
# Proced 01 Principal (cod+des)
# 87    2908
# 88    1994
# 73    1651
# 74    1219
# 89     722
# Name: count, dtype: int64
#
# Proced 02 Secundario (cod+des):
# Proced 02 Secundario (cod+des)
# 88    2656
# 89    2248
# 99    1501
# 87    1378
# 75    1360
# Name: count, dtype: int64
#
# Proced 03 Secundario (cod+des):
# Proced 03 Secundario (cod+des)
# 90    2602
# 99    2565
# 89    2132
# 88    1731
# 03    1193
# Name: count, dtype: int64
#
# Proced 04 Secundario (cod+des):
# Proced 04 Secundario (cod+des)
# 99    3448
# 90    2789
# 89    2120
# 88    1158
# 03     885
# Name: count, dtype: int64
#
# Proced 05 Secundario (cod+des):
# Proced 05 Secundario (cod+des)
# 99    4206
# 90    2923
# 89    1914
# -      962
# 93     912
# Name: count, dtype: int64
#
# Proced 06 Secundario (cod+des):
# Proced 06 Secundario (cod+des)
# 99    4320
# 90    2820
# 89    1771
# -     1480
# 93    1154
# Name: count, dtype: int64
#
# Proced 07 Secundario (cod+des):
# Proced 07 Secundario (cod+des)
# 99    4438
# 90    2378
# -     2135
# 89    1790
# 93    1346
# Name: count, dtype: int64
#
# Proced 08 Secundario (cod+des):
# Proced 08 Secundario (cod+des)
# 99    4102
# -     3012
# 90    1951
# 89    1731
# 93    1559
# Name: count, dtype: int64
#
# Proced 09 Secundario (cod+des):
# Proced 09 Secundario (cod+des)
# -     3937
# 99    3422
# 90    1867
# 89    1669
# 93    1668
# Name: count, dtype: int64
#
# Proced 10 Secundario (cod+des):
# Proced 10 Secundario (cod+des)
# -     4982
# 99    2950
# 93    1761
# 89    1680
# 90    1385
# Name: count, dtype: int64
#
# Proced 11 Secundario (cod+des):
# Proced 11 Secundario (cod+des)
# -     6091
# 99    2257
# 93    1852
# 89    1596
# 90    1123
# Name: count, dtype: int64
#
# Proced 12 Secundario (cod+des):
# Proced 12 Secundario (cod+des)
# -     7341
# 93    1892
# 99    1811
# 89    1353
# 90     869
# Name: count, dtype: int64
#
# Proced 13 Secundario (cod+des):
# Proced 13 Secundario (cod+des)
# -     8446
# 93    1929
# 99    1350
# 89    1072
# 90     665
# Name: count, dtype: int64
#
# Proced 14 Secundario (cod+des):
# Proced 14 Secundario (cod+des)
# -     9359
# 93    1912
# 99    1031
# 89     827
# 90     564
# Name: count, dtype: int64
#
# Proced 15 Secundario (cod+des):
# Proced 15 Secundario (cod+des)
# -     10111
# 93     1874
# 99      800
# 89      663
# 90      388
# Name: count, dtype: int64
#
# Proced 16 Secundario (cod+des):
# Proced 16 Secundario (cod+des)
# -     10667
# 93     1783
# 99      653
# 89      522
# 90      346
# Name: count, dtype: int64
#
# Proced 17 Secundario (cod+des):
# Proced 17 Secundario (cod+des)
# -     11076
# 93     1718
# 99      541
# 89      395
# 90      298
# Name: count, dtype: int64
#
# Proced 18 Secundario (cod+des):
# Proced 18 Secundario (cod+des)
# -     11391
# 93     1587
# 99      467
# 89      361
# 90      273
# Name: count, dtype: int64
#
# Proced 19 Secundario (cod+des):
# Proced 19 Secundario (cod+des)
# -     11667
# 93     1496
# 99      422
# 89      292
# 90      252
# Name: count, dtype: int64
#
# Proced 20 Secundario (cod+des):
# Proced 20 Secundario (cod+des)
# -     11913
# 93     1394
# 99      408
# 89      274
# 90      204
# Name: count, dtype: int64
#
# Proced 21 Secundario (cod+des):
# Proced 21 Secundario (cod+des)
# -     12120
# 93     1289
# 99      365
# 89      273
# 90      198
# Name: count, dtype: int64
#
# Proced 22 Secundario (cod+des):
# Proced 22 Secundario (cod+des)
# -     12321
# 93     1170
# 99      327
# 89      227
# 90      173
# Name: count, dtype: int64
#
# Proced 23 Secundario (cod+des):
# Proced 23 Secundario (cod+des)
# -     12496
# 93     1071
# 99      267
# 89      228
# 90      161
# Name: count, dtype: int64
#
# Proced 24 Secundario (cod+des):
# Proced 24 Secundario (cod+des)
# -     12666
# 93      969
# 99      251
# 89      232
# 90      137
# Name: count, dtype: int64
#
# Proced 25 Secundario (cod+des):
# Proced 25 Secundario (cod+des)
# -     12851
# 93      893
# 99      228
# 89      183
# 90      131
# Name: count, dtype: int64
#
# Proced 26 Secundario (cod+des):
# Proced 26 Secundario (cod+des)
# -     12989
# 93      799
# 99      206
# 89      197
# 90      116
# Name: count, dtype: int64
#
# Proced 27 Secundario (cod+des):
# Proced 27 Secundario (cod+des)
# -     13138
# 93      754
# 89      170
# 99      164
# 90      113
# Name: count, dtype: int64
#
# Proced 28 Secundario (cod+des):
# Proced 28 Secundario (cod+des)
# -     13261
# 93      674
# 89      153
# 99      148
# 90      107
# Name: count, dtype: int64
#
# Proced 29 Secundario (cod+des):
# Proced 29 Secundario (cod+des)
# -     13379
# 93      623
# 99      151
# 89      135
# 90       99
# Name: count, dtype: int64
#
# Proced 30 Secundario (cod+des):
# Proced 30 Secundario (cod+des)
# -     13498
# 93      551
# 89      127
# 99      121
# 90       95
# Name: count, dtype: int64
#
# GRD:
# GRD
# 146101 - PH CESÁREA                                                                       813
# 146121 - PH PARTO VAGINAL CON PROCED., EXCEPTO ESTERILIZACIÓN Y/O DILATACIÓN Y LEGRADO    639
# 146131 - PH PARTO VAGINAL                                                                 538
# 158171 - MH NEONATO, PESO AL NACER >2499 GR SIN PROCEDIMIENTO MAYOR                       389
# 134161 - MH TRASTORNOS DEL ANTEPARTO                                                      325
# Name: count, dtype: int64

# %%
df
# Out:
#                              Diag 01 Principal (cod+des)  \
# 0                A41.8 - Otras septicemias especificadas
# 1                   U07.1 - COVID-19, virus identificado
# 2      K56.5 - Adherencias [bridas] intestinales con ...
# 3      K76.8 - Otras enfermedades especificadas del h...
# 4      T81.0 - Hemorragia y hematoma que complican un...
# ...                                                  ...
# 14556  E10.1 - Diabetes mellitus tipo 1 con cetoacidosis
# 14557  S09.9 - Traumatismo de la cabeza, no especificado
# 14558                                     K92.1 - Melena
# 14559                     E78.1 - Hipergliceridemia pura
# 14560  S06.51 - Hemorragia subdural traumática, con h...
#
#                             Diag 02 Secundario (cod+des)  \
# 0         B37.6 - Endocarditis debida a candida (I39.8*)
# 1                  J12.8 - Neumonía debida a otros virus
# 2                                  R57.2 - Shock séptico
# 3                                  K66.1 - Hemoperitoneo
# 4      Y83.2 - Operación quirúrgica con anastomosis, ...
# ...                                                  ...
# 14556                      J45.9 - Asma, no especificada
# 14557  W18.24 - Otras caídas en el mismo nivel, escue...
# 14558             I10 - Hipertensión esencial (primaria)
# 14559             I10 - Hipertensión esencial (primaria)
# 14560  S06.21 - Traumatismo cerebral difuso, con heri...
#
#                             Diag 03 Secundario (cod+des)  \
# 0      I39.8 - Endocarditis, válvula no especificada,...
# 1                                         R06.0 - Disnea
# 2                            R57.1 - Choque hipovolémico
# 3            N18.5 - Enfermedad renal crónica, estadio 5
# 4                   S31.1 - Herida de la pared abdominal
# ...                                                  ...
# 14556  F10.2 - Trastornos mentales y del comportamien...
# 14557                            R55 - Síncope y colapso
# 14558  E11.9 - Diabetes mellitus tipo 2 sin complicac...
# 14559  Z92.2 - Historia personal de uso (presente) de...
# 14560  W18.09 - Otras caídas en el mismo nivel, vivie...
#
#                             Diag 04 Secundario (cod+des)  \
# 0                N10 - Nefritis tubulointersticial aguda
# 1                                              R05 - Tos
# 2      J80 - Síndrome de dificultad respiratoria del ...
# 3                 D64.9 - Anemia de tipo no especificado
# 4      S36.80 - Traumatismo de otros órganos intraabd...
# ...                                                  ...
# 14556  F17.2 - Trastornos mentales y del comportamien...
# 14557                                                  -
# 14558    I50.9 - Insuficiencia cardíaca, no especificada
# 14559                                                  -
# 14560  J69.0 - Neumonitis debida a aspiración de alim...
#
#                             Diag 05 Secundario (cod+des)  \
# 0      B96.1 - Klebsiella pneumoniae [K. pneumoniae] ...
# 1                        R50.9 - Fiebre, no especificada
# 2                              Y95 - Afección nosocomial
# 3                                 E87.5 - Hiperpotasemia
# 4      W31.62 - Contacto traumático con otras maquina...
# ...                                                  ...
# 14556  Z91.1 - Historia personal de incumplimiento de...
# 14557                                                  -
# 14558  K25.9 - Úlcera gástrica, no especificada como ...
# 14559                                                  -
# 14560               D29.1 - Tumor benigno de la próstata
#
#                             Diag 06 Secundario (cod+des)  \
# 0      L89.9 - Úlcera de decúbito y area de presión n...
# 1                                    Z29.0 - Aislamiento
# 2        J15.0 - Neumonía debida a Klebsiella pneumoniae
# 3                                       E87.2 - Acidosis
# 4      J96.09 - Insuficiencia respiratoria aguda, Tip...
# ...                                                  ...
# 14556                                                  -
# 14557                                                  -
# 14558               M16.9 - Coxartrosis, no especificada
# 14559                                                  -
# 14560  Z59.0 - Problemas relacionados con la falta de...
#
#                             Diag 07 Secundario (cod+des)  \
# 0      L08.9 - Infección local de la piel y del tejid...
# 1                          Z01.7 - Examen de laboratorio
# 2      U82.2 - Resistencia a Betalactamasas de amplio...
# 3                                   J81 - Edema pulmonar
# 4        J15.0 - Neumonía debida a Klebsiella pneumoniae
# ...                                                  ...
# 14556                                                  -
# 14557                                                  -
# 14558                            G47.3 - Apnea del sueño
# 14559                                                  -
# 14560            Z02.7 - Extensión de certificado médico
#
#                             Diag 08 Secundario (cod+des)  \
# 0      B96.2 - Escherichia coli [E. coli] como causa ...
# 1      J96.00 - Insuficiencia respiratoria aguda, Tip...
# 2      B95.6 - Staphylococcus aureus como causa de en...
# 3            N17.8 - Otras insuficiencias renales agudas
# 4      U82.2 - Resistencia a Betalactamasas de amplio...
# ...                                                  ...
# 14556                                                  -
# 14557                                                  -
# 14558  Z99.8 - Dependencia de otras máquinas y dispos...
# 14559                                                  -
# 14560                                                  -
#
#                             Diag 09 Secundario (cod+des)  \
# 0      A41.5 - Sepsis por otros organnismos Gram nega...
# 1                                      J94.2 - Hemotórax
# 2      B96.8 - Otros agentes bacterianos especificado...
# 3      J44.9 - Enfermedad pulmonar obstructiva crónic...
# 4                   U07.1 - COVID-19, virus identificado
# ...                                                  ...
# 14556                                                  -
# 14557                                                  -
# 14558                                                  -
# 14559                                                  -
# 14560                                                  -
#
#                             Diag 10 Secundario (cod+des)  ...  \
# 0                           J86.9 - Piotórax sin fístula  ...
# 1                  J92.9 - Paquipleuritis sin asbestosis  ...
# 2                           B37.1 - Candidiasis pulmonar  ...
# 3                 R41.0 - Desorientación no especificada  ...
# 4      N39.0 - Infección de vías urinarias, sitio no ...  ...
# ...                                                  ...  ...
# 14556                                                  -  ...
# 14557                                                  -  ...
# 14558                                                  -  ...
# 14559                                                  -  ...
# 14560                                                  -  ...
#
#                    Proced 24 Secundario (cod+des)  \
# 0                             99.84 - AISLAMIENTO
# 1        91.62 - EXAMEN MICROSCOPICO PIEL.CULTIVO
# 2                             99.84 - AISLAMIENTO
# 3             57.94 - SONDAJE URINARIO PERMANENTE
# 4      90.52 - EXAMEN MICROSCOPICO SANGRE.CULTIVO
# ...                                           ...
# 14556                                           -
# 14557                                           -
# 14558                                           -
# 14559                                           -
# 14560                     89.66 - GASOMETRIA VENA
#
#                           Proced 25 Secundario (cod+des)  \
# 0                                88.72 - ECOCARDIOGRAFIA
# 1      90.43 - EXAMEN MICROSCOPICO RESPIRATORIO.CULTI...
# 2      91.73 - EXAMEN MICROSCOPICO HERIDA OPERATORIA....
# 3                           00.13 - INYECCION NESIRITIDE
# 4      91.39 - EXAMEN MICROSCOPICO URINARIO INFERIOR....
# ...                                                  ...
# 14556                                                  -
# 14557                                                  -
# 14558                                                  -
# 14559                                                  -
# 14560                            89.66 - GASOMETRIA VENA
#
#                           Proced 26 Secundario (cod+des)  \
# 0       90.42 - EXAMEN MICROSCOPICO RESPIRATORIO.CULTIVO
# 1      91.39 - EXAMEN MICROSCOPICO URINARIO INFERIOR....
# 2      90.53 - EXAMEN MICROSCOPICO SANGRE.CULTIVO Y S...
# 3                      00.17 - INFUSON AGENTE VASOPRESOR
# 4      91.32 - EXAMEN MICROSCOPICO URINARIO INFERIOR....
# ...                                                  ...
# 14556                                                  -
# 14557                                                  -
# 14558                                                  -
# 14559                                                  -
# 14560               90.39 - EXAMEN MICROSCOPICO ORL.OTRO
#
#                           Proced 27 Secundario (cod+des)  \
# 0             90.52 - EXAMEN MICROSCOPICO SANGRE.CULTIVO
# 1             90.52 - EXAMEN MICROSCOPICO SANGRE.CULTIVO
# 2                       99.26 - INYECCION TRANQUILIZANTE
# 3               99.04 - TRANSFUSION CONCENTRADO HEMATIES
# 4      93.90 - RESPIRACION PRESION POSITIVA CONTINUA ...
# ...                                                  ...
# 14556                                                  -
# 14557                                                  -
# 14558                                                  -
# 14559                                                  -
# 14560   90.42 - EXAMEN MICROSCOPICO RESPIRATORIO.CULTIVO
#
#                           Proced 28 Secundario (cod+des)  \
# 0      91.39 - EXAMEN MICROSCOPICO URINARIO INFERIOR....
# 1      91.32 - EXAMEN MICROSCOPICO URINARIO INFERIOR....
# 2      89.39 - OTRAS MEDICIONES Y EXAMENES NO QUIRURG...
# 3                          99.18 - INYECCION ELECTROLITO
# 4      99.15 - INFUSION PARENTERAL SUSTANCIA NUTRITIV...
# ...                                                  ...
# 14556                                                  -
# 14557                                                  -
# 14558                                                  -
# 14559                                                  -
# 14560         90.52 - EXAMEN MICROSCOPICO SANGRE.CULTIVO
#
#                           Proced 29 Secundario (cod+des)  \
# 0      91.33 - EXAMEN MICROSCOPICO URINARIO INFERIOR....
# 1                         96.59 - IRRIGACION HERIDA OTRA
# 2                                89.66 - GASOMETRIA VENA
# 3                          99.21 - INYECCION ANTIBIOTICO
# 4                         96.59 - IRRIGACION HERIDA OTRA
# ...                                                  ...
# 14556                                                  -
# 14557                                                  -
# 14558                                                  -
# 14559                                                  -
# 14560            90.59 - EXAMEN MICROSCOPICO SANGRE.OTRO
#
#                           Proced 30 Secundario (cod+des) Edad en años  \
# 0          87.03 - TOMOGRAFIA AXIAL COMPUTERIZADA CABEZA           40
# 1      90.99 - EXAMEN MICROSCOPICO DIGESTIVO INFERIOR...           53
# 2                             89.65 - GASOMETRIA ARTERIA           65
# 3                            99.23 - INYECCION ESTEROIDE           61
# 4               45.13 - ESOFAGOGASTRODUODENOSCOPIA [EGD]           30
# ...                                                  ...          ...
# 14556                                                  -           26
# 14557                                                  -           10
# 14558                                                  -           58
# 14559                                                  -           47
# 14560            90.59 - EXAMEN MICROSCOPICO SANGRE.OTRO           73
#
#       Sexo (Desc)                                                GRD
# 0          Hombre                       184103 - MH SEPTICEMIA W/MCC
# 1          Hombre  041013 - PH ECMO VENTILACIÓN MECÁNICA PROLONGA...
# 2          Hombre  041013 - PH ECMO VENTILACIÓN MECÁNICA PROLONGA...
# 3          Hombre  041023 - PH VENTILACIÓN MECÁNICA PROLONGADA SI...
# 4          Hombre  041023 - PH VENTILACIÓN MECÁNICA PROLONGADA SI...
# ...           ...                                                ...
# 14556       Mujer  104101 - MH DIABETES Y ENFERMEDADES METABÓLICA...
# 14557      Hombre              014242 - MH TRAUMATISMO CEFÁLICO W/CC
# 14558      Hombre  064182 - MH OTROS DIAGNÓSTICOS SOBRE APARATO D...
# 14559      Hombre      104121 - MH ERRORES CONGÉNITOS DE METABOLISMO
# 14560      Hombre  041203 - PH PROCEDIMIENTOS NO COMPLEJOS SOBRE ...
#
# [14561 rows x 68 columns]

# %%
df_categoria
# Out:
#        Edad en años  Sexo (Desc)  \
# 0                40            1
# 1                53            1
# 2                65            1
# 3                61            1
# 4                30            1
# ...             ...          ...
# 14556            26            0
# 14557            10            1
# 14558            58            1
# 14559            47            1
# 14560            73            1
#
#                                                      GRD  \
# 0                           184103 - MH SEPTICEMIA W/MCC
# 1      041013 - PH ECMO VENTILACIÓN MECÁNICA PROLONGA...
# 2      041013 - PH ECMO VENTILACIÓN MECÁNICA PROLONGA...
# 3      041023 - PH VENTILACIÓN MECÁNICA PROLONGADA SI...
# 4      041023 - PH VENTILACIÓN MECÁNICA PROLONGADA SI...
# ...                                                  ...
# 14556  104101 - MH DIABETES Y ENFERMEDADES METABÓLICA...
# 14557              014242 - MH TRAUMATISMO CEFÁLICO W/CC
# 14558  064182 - MH OTROS DIAGNÓSTICOS SOBRE APARATO D...
# 14559      104121 - MH ERRORES CONGÉNITOS DE METABOLISMO
# 14560  041203 - PH PROCEDIMIENTOS NO COMPLEJOS SOBRE ...
#
#        Diag 01 Principal (cod+des)_A02  Diag 01 Principal (cod+des)_A04  \
# 0                                False                            False
# 1                                False                            False
# 2                                False                            False
# 3                                False                            False
# 4                                False                            False
# ...                                ...                              ...
# 14556                            False                            False
# 14557                            False                            False
# 14558                            False                            False
# 14559                            False                            False
# 14560                            False                            False
#
#        Diag 01 Principal (cod+des)_A05  Diag 01 Principal (cod+des)_A06  \
# 0                                False                            False
# 1                                False                            False
# 2                                False                            False
# 3                                False                            False
# 4                                False                            False
# ...                                ...                              ...
# 14556                            False                            False
# 14557                            False                            False
# 14558                            False                            False
# 14559                            False                            False
# 14560                            False                            False
#
#        Diag 01 Principal (cod+des)_A08  Diag 01 Principal (cod+des)_A09  \
# 0                                False                            False
# 1                                False                            False
# 2                                False                            False
# 3                                False                            False
# 4                                False                            False
# ...                                ...                              ...
# 14556                            False                            False
# 14557                            False                            False
# 14558                            False                            False
# 14559                            False                            False
# 14560                            False                            False
#
#        Diag 01 Principal (cod+des)_A15  ...  \
# 0                                False  ...
# 1                                False  ...
# 2                                False  ...
# 3                                False  ...
# 4                                False  ...
# ...                                ...  ...
# 14556                            False  ...
# 14557                            False  ...
# 14558                            False  ...
# 14559                            False  ...
# 14560                            False  ...
#
#        Proced 30 Secundario (cod+des)_88  Proced 30 Secundario (cod+des)_89  \
# 0                                  False                              False
# 1                                  False                              False
# 2                                  False                               True
# 3                                  False                              False
# 4                                  False                              False
# ...                                  ...                                ...
# 14556                              False                              False
# 14557                              False                              False
# 14558                              False                              False
# 14559                              False                              False
# 14560                              False                              False
#
#        Proced 30 Secundario (cod+des)_90  Proced 30 Secundario (cod+des)_91  \
# 0                                  False                              False
# 1                                   True                              False
# 2                                  False                              False
# 3                                  False                              False
# 4                                  False                              False
# ...                                  ...                                ...
# 14556                              False                              False
# 14557                              False                              False
# 14558                              False                              False
# 14559                              False                              False
# 14560                               True                              False
#
#        Proced 30 Secundario (cod+des)_93  Proced 30 Secundario (cod+des)_94  \
# 0                                  False                              False
# 1                                  False                              False
# 2                                  False                              False
# 3                                  False                              False
# 4                                  False                              False
# ...                                  ...                                ...
# 14556                              False                              False
# 14557                              False                              False
# 14558                              False                              False
# 14559                              False                              False
# 14560                              False                              False
#
#        Proced 30 Secundario (cod+des)_95  Proced 30 Secundario (cod+des)_96  \
# 0                                  False                              False
# 1                                  False                              False
# 2                                  False                              False
# 3                                  False                              False
# 4                                  False                              False
# ...                                  ...                                ...
# 14556                              False                              False
# 14557                              False                              False
# 14558                              False                              False
# 14559                              False                              False
# 14560                              False                              False
#
#        Proced 30 Secundario (cod+des)_97  Proced 30 Secundario (cod+des)_99
# 0                                  False                              False
# 1                                  False                              False
# 2                                  False                              False
# 3                                  False                               True
# 4                                  False                              False
# ...                                  ...                                ...
# 14556                              False                              False
# 14557                              False                              False
# 14558                              False                              False
# 14559                              False                              False
# 14560                              False                              False
#
# [14561 rows x 10247 columns]
