# %% [markdown]
# ## Pruebas de Encoding
# Debido a la alta cardinalidad de ciertas variables, es necesario buscar opciones que no sean directamente One Hot Encoding.
# En el siguiente cuaderno se testearan encodings como:
# - Target Encoding
# - Frecuency Encoding
# - Ordinal Encoding
# - Keep Top N Categories
# - Binary Encoding

# %%
from sklearn.preprocessing import TargetEncoder
df_target = df.copy()

cols_diag = [c for c in df.columns if 'Diag' in c and '(cod+des)' in c]
cols_proc = [c for c in df.columns if 'Proced' in c and '(cod+des)' in c]

X= df[cols_diag + cols_proc]  
y = df['GRD']
y.info()


# encoder = TargetEncoder()
# X_encoded = encoder.fit_transform(X,y)


# df_target.describe()
# df_target
# Out:
# <class 'pandas.Series'>
# RangeIndex: 14561 entries, 0 to 14560
# Series name: GRD
# Non-Null Count  Dtype
# --------------  -----
# 14561 non-null  int64
# dtypes: int64(1)
# memory usage: 113.9 KB
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# 2. Testeo con category_encoders

# %%
from category_encoders import TargetEncoder as CE_TargetEncoder


encoder2 = CE_TargetEncoder()
X_encoded2 = encoder2.fit_transform(X,y)

X_encoded2 = pd.DataFrame(X_encoded2, columns=X.columns)
df_target2 = pd.concat([df_target, X_encoded2], axis=1)
df_target2
# Out:
#       Diag 01 Principal (cod+des) Diag 02 Secundario (cod+des)  \
# 0                             A41                          B37
# 1                             U07                          J12
# 2                             K56                          R57
# 3                             K76                          K66
# 4                             T81                          Y83
# ...                           ...                          ...
# 14556                         E10                          J45
# 14557                         S09                          W18
# 14558                         K92                          I10
# 14559                         E78                          I10
# 14560                         S06                          S06
#
#       Diag 03 Secundario (cod+des) Diag 04 Secundario (cod+des)  \
# 0                              I39                          N10
# 1                              R06                          R05
# ...

# %% [markdown]
# ## Binary Encoding
