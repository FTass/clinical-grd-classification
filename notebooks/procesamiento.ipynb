# %% [markdown]
# ## Pruebas de Encoding
# Debido a la alta cardinalidad de ciertas variables, es necesario buscar opciones que no sean directamente One Hot Encoding.
# En el siguiente cuaderno se testearan encodings como:
# - Target Encoding
# - Frecuency Encoding
# - Ordinal Encoding
# - Keep Top N Categories
# - Binary Encoding

# %%
import pandas as pd

df = pd.read_csv('../data/processed/elpino_categories.csv')
df.head()
# Out:
#   Diag 01 Principal (cod+des) Diag 02 Secundario (cod+des)  \
# 0                         A41                          B37
# 1                         U07                          J12
# 2                         K56                          R57
# 3                         K76                          K66
# 4                         T81                          Y83
#
#   Diag 03 Secundario (cod+des) Diag 04 Secundario (cod+des)  \
# 0                          I39                          N10
# 1                          R06                          R05
# 2                          R57                          J80
# 3                          N18                          D64
# 4                          S31                          S36
#
#   Diag 05 Secundario (cod+des) Diag 06 Secundario (cod+des)  \
# 0                          B96                          L89
# 1                          R50                          Z29
# 2                          Y95                          J15
# ...

# %% [markdown]
# # Target encoding

# %%
df_target = df.copy()
