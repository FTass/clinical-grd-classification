# %%
import pandas as pd


df = pd.read_csv('../data/processed/elpino_categories.csv')
df_encodeado = df.copy()

col_diag = [c for c in df.columns if 'Diag' in c and "(cod+des)"in c]
col_proc= [c for c in df.columns if 'Proced' in c and "(cod+des)"in c]
df_encodeado
# Out:
#       Diag 01 Principal (cod+des) Diag 02 Secundario (cod+des)  \
# 0                             A41                          B37
# 1                             U07                          J12
# 2                             K56                          R57
# 3                             K76                          K66
# 4                             T81                          Y83
# ...                           ...                          ...
# 14556                         E10                          J45
# 14557                         S09                          W18
# 14558                         K92                          I10
# 14559                         E78                          I10
# 14560                         S06                          S06
#
#       Diag 03 Secundario (cod+des) Diag 04 Secundario (cod+des)  \
# 0                              I39                          N10
# 1                              R06                          R05
# ...

# %%
cols_diag = [c for c in df.columns if "Diag" in c]

df_encodeado["diagnosticos"] = df[cols_diag].values.tolist()
df_encodeado
# Out:
#       Diag 01 Principal (cod+des) Diag 02 Secundario (cod+des)  \
# 0                             A41                          B37
# 1                             U07                          J12
# 2                             K56                          R57
# 3                             K76                          K66
# 4                             T81                          Y83
# ...                           ...                          ...
# 14556                         E10                          J45
# 14557                         S09                          W18
# 14558                         K92                          I10
# 14559                         E78                          I10
# 14560                         S06                          S06
#
#       Diag 03 Secundario (cod+des) Diag 04 Secundario (cod+des)  \
# 0                              I39                          N10
# 1                              R06                          R05
# ...

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Embedding, Flatten, Dense

# Convertir códigos a índices
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()


X_diag = mlb.fit_transform(df_encodeado["diagnosticos"])
X_diag
df_encodeado
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 9
#       5 from sklearn.preprocessing import LabelEncoder
#       6 le = LabelEncoder()
#       7
#       8
# ----> 9 X_diag = mlb.fit_transform(df_encodeado["diagnosticos"])
#      10 X_diag
#      11 df_encodeado
#
# NameError: name 'mlb' is not defined

# %%
df

col_grd = [c for c in df.columns if 'GRD' in c]
col_grd
for col in col_grd:
    df[col] = (
        df[col].str.split(" - ").str[0]
    )
df.to_csv('../data/processed/elpino_categories.csv', index=False)
